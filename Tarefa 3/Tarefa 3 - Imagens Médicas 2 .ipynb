# %% [markdown]
# ---
#
# Universidade Federal de Uberlândia
#
# Faculdade de Engenharia Elétrica
#
# Imagens Médicas 2
#
# Discente: Levy Gabriel da S. G.
#
# ---

# %%
from IPython.display import Image

def imageNcaption(filename, caption):
    display(Image(filename=filename))
    print(caption)

# %% [markdown]
# # Tarefa 3 - Análise preliminar de uma imagem

# %% [markdown]
# A imagem da figura 1 será o foco das análises da presente tarefa. Suas propriedades são:
#
# - 512 linhas por 512 colunas;
# - 16 bits de profundidade;

# %%
imageNcaption('tarefa3.png', 'Figura 1 - Imagem a ser analisada.')
# Out:
# Figura 1 - Imagem a ser analisada.

# %% [markdown]
# ## Resolução espacial

# %% [markdown]
# As dimensões espaciais da imagem são de 20 cm por 20 cm ou 200 mm por 200 mm. Como cada linha ou coluna possui 512 pixels, o tamanho de cada pixel pode ser encontrado pela razão entre a distância e a quantidade de pixels:

# %%
print('Tamanho do pixel: ' + str(200/512) + ' mm')
# Out:
# Tamanho do pixel: 0.390625 mm

# %% [markdown]
# Para encontrar esse resultado em DPI (*dots per inch*) basta converter as dimensões físicas para polegadas e computar a razão entre a quantidade de pixels pela distância em polegadas:

# %%
print(str(200) + ' mm equivale a ' + str(200/25.4) + ' polegadas') 
print('Tamanho do pixel: ' + str(512/(200/25.4)) + ' DPI')
# Out:
# 200 mm equivale a 7.874015748031496 polegadas
# Tamanho do pixel: 65.024 DPI

# %% [markdown]
# ## Quantidade de bytes para armazenar a imagem

# %% [markdown]
# Considerando-se que cada byte é composto por 8 bits e, uma vez que a profundidade da imagem de análise é de 16 bits, isso significa dizer que cada pixel ocupará um espaço de armazenamento de 16 bits ou 2 bytes.
#
# Como a imagem por completo possui 512 linhas e 512 colunas, a multiplicação destes dois valores resultará na quantidade de pixels da imagem, ou seja:

# %%
print('Total de pixels na imagem: ' + str(512*512) + ' pixels')
# Out:
# Total de pixels na imagem: 262144 pixels

# %% [markdown]
# Como cada pixels ocupa 2 bytes, o total de bytes para armazenar a imagem será (MB = megabytes):

# %%
print('Espaço necessário para armazenar a imagem: ')
print(str(512*512*2) + ' bytes, ou')
print(str(512*512*2/1e6) + ' MB')
# Out:
# Espaço necessário para armazenar a imagem:
# 524288 bytes, ou
# 0.524288 MB
